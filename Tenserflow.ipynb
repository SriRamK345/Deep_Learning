# %% [markdown]
# <a href="https://colab.research.google.com/github/SriRamK345/Deep_Learning/blob/main/Tenserflow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
print("TensorFlow version:", tf.__version__)
# Out:
# TensorFlow version: 2.17.0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
tf.constant("hello world")
# Out:
# <tf.Tensor: shape=(), dtype=string, numpy=b'hello world'>

# %%
tf.constant(1)
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=1>

# %%
x = tf.constant(3.0)
print(x)
# Out:
# tf.Tensor(3.0, shape=(), dtype=float32)

# %%
x = tf.constant([1,2,3])
print(x)
# Out:
# tf.Tensor([1 2 3], shape=(3,), dtype=int32)

# %%
x = tf.constant([[1,2,3],[4,5,6]])
print(x)
# Out:
# tf.Tensor(
# [[1 2 3]
#  [4 5 6]], shape=(2, 3), dtype=int32)

# %% [markdown]
# # Variable

# %%
x = tf.Variable([1,2,3], dtype=tf.float32, name = "summa")
print(x)
# Out:
# <tf.Variable 'summa:0' shape=(3,) dtype=float32, numpy=array([1., 2., 3.], dtype=float32)>

# %%
print(x.numpy())
print(x.shape)
print(x.dtype)
# Out:
# [1. 2. 3.]
# (3,)
# <dtype: 'float32'>

# %% [markdown]
# # reshape

# %%
x = tf.constant([[1,2,3],[4,5,6]])
tf.reshape(x, (3,2))
# Out:
# <tf.Tensor: shape=(3, 2), dtype=int32, numpy=
# array([[1, 2],
#        [3, 4],
#        [5, 6]], dtype=int32)>

# %%
x = tf.constant([[1,2,3],[4,5,6]])
tf.reshape(x, (-1))
# Out:
# <tf.Tensor: shape=(6,), dtype=int32, numpy=array([1, 2, 3, 4, 5, 6], dtype=int32)>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
x = tf.constant([[1,2,3,6],[4,5,6,-7]])
tf.reshape(x, (2,-1))
# Out:
# <tf.Tensor: shape=(2, 4), dtype=int32, numpy=
# array([[ 1,  2,  3,  6],
#        [ 4,  5,  6, -7]], dtype=int32)>

# %% [markdown]
# # Access element

# %%
x = tf.constant([[1,2,3,6],[4,5,6,-7]])
tf.argmax(x)
# Out:
# <tf.Tensor: shape=(4,), dtype=int64, numpy=array([1, 1, 1, 0])>

# %%
x = tf.constant([[1,2,3,6],[4,5,6,-7]])
tf.argmin(x)
# Out:
# <tf.Tensor: shape=(4,), dtype=int64, numpy=array([0, 0, 0, 1])>

# %% [markdown]
# # 1. Sequential API

# %%
from tensorflow import keras
from tensorflow.keras import layers

model = keras.Sequential([
    layers.Dense(64, activation='relu', input_shape=(input_size,)),
    layers.Dense(32, activation='relu'),
    layers.Dense(1, activation='sigmoid')
])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-c0de998edc81> in <cell line: 4>()
#       3
#       4 model = keras.Sequential([
# ----> 5     layers.Dense(64, activation='relu', input_shape=(input_size,)),
#       6     layers.Dense(32, activation='relu'),
#       7     layers.Dense(1, activation='sigmoid')
#
# NameError: name 'input_size' is not defined

# %% [markdown]
# ![image.png](data:image/png;base64,...)
